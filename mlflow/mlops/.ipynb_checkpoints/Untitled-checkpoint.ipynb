# %%
import matplotlib.pyplot as plt
plt
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <module 'matplotlib.pyplot' from '/Users/keshavsrisai/Documents/Pyproject/mlenv/lib/python3.13/site-packages/matplotlib/pyplot.py'>
