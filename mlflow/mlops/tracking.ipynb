# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("my_experiment_test")

with mlflow.start_run():
    mlflow.log_param("param1", 5)
    mlflow.log_metric("metric1", 0.85)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mlflow.set_experiment("my_experiment_test")
#       3 with mlflow.start_run():
#       4     mlflow.log_param("param1", 5)
#
# File ~/Documents/Pyproject/mlenv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:184, in set_experiment(experiment_name, experiment_id)
#     182 with _experiment_lock:
#     183     if experiment_id is None:
# --> 184         experiment = client.get_experiment_by_name(experiment_name)
#     185         if not experiment:
#     186             _logger.info(
#     187                 "Experiment with name '%s' does not exist. Creating a new experiment.",
#     188                 experiment_name,
#     189             )
#
# ...
